# %% [markdown]
# # <center> <h1> Problem 2 <font> </h1> </center>

# %% [markdown]
# # <h4><font color='red'> Plotting the US population </font> </h4>

# %% [markdown]
# # <h4><font color='red'> load libaries </font> </h4>

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
#set working directory
path = "C:\\Users\\91886\\Downloads"
os.chdir(path)

# %%
a = pd.read_csv('ACSST5Y2020.S0101-2022-11-29T230101.csv')
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a
# Out:
#                              Label (Grouping) United States!!Total!!Estimate  \
# 0                            Total population                    326,569,308
# 1                                         AGE                            NaN
# 2                               Under 5 years                     19,650,192
# 3                                5 to 9 years                     19,979,039
# 4                              10 to 14 years                     21,107,910
# 5                              15 to 19 years                     21,174,955
# 6                              20 to 24 years                     21,820,378
# 7                              25 to 29 years                     23,262,155
# 8                              30 to 34 years                     22,223,010
# 9                              35 to 39 years                     21,346,055
# 10                             40 to 44 years                     20,000,622
# ...

# %%
b = pd.read_csv("ACSST1Y2010.S0101-2022-11-29T230224.csv")
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b
# Out:
#                          Label (Grouping) United States!!Total!!Estimate  \
# 0                        Total population                    309,349,689
# 1                                     AGE                            NaN
# 2                           Under 5 years                           6.5%
# 3                            5 to 9 years                           6.6%
# 4                          10 to 14 years                           6.7%
# 5                          15 to 19 years                           7.1%
# 6                          20 to 24 years                           7.0%
# 7                          25 to 29 years                           6.8%
# 8                          30 to 34 years                           6.5%
# 9                          35 to 39 years                           6.5%
# 10                         40 to 44 years                           6.8%
# 11                         45 to 49 years                           7.3%
# ...

# %%
pop = a[['United States!!Male!!Estimate']]
pop.head()
# Out:
#   United States!!Male!!Estimate
# 0                   160,818,530
# 1                           NaN
# 2                    10,051,876
# 3                    10,191,107
# 4                    10,797,748

# %%
pop1 = b[['United States!!Male!!Estimate']]
pop1.head()
# Out:
#   United States!!Male!!Estimate
# 0                   152,089,450
# 1                           NaN
# 2                          6.8%
# 3                          6.8%
# 4                          7.0%
